# %%
import pandas as pd

# %%
df = pd.read_csv('football/2025_player_stats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Rk             Player                             Player_Href  \
# 0           1   1         Max Aarons         /en/players/774cf58b/Max-Aarons
# 1           2   2  Joshua Acheampong  /en/players/b7e62e1d/Joshua-Acheampong
# 2           3   3        Tyler Adams        /en/players/2b09d998/Tyler-Adams
# 3           4   4   Tosin Adarabioyo   /en/players/c81d773d/Tosin-Adarabioyo
# 4           5   5      Simon Adingra      /en/players/4dcec659/Simon-Adingra
#
#     Nation    Pos        Squad   Age    Born  MP_Playing Time  ...  \
# 0  eng ENG     DF  Bournemouth  24.0  2000.0                3  ...
# 1  eng ENG     DF      Chelsea  18.0  2006.0                4  ...
# 2   us USA     MF  Bournemouth  25.0  1999.0               28  ...
# 3  eng ENG     DF      Chelsea  26.0  1997.0               22  ...
# 4   ci CIV  FW,MF     Brighton  22.0  2002.0               29  ...
#
#    G+A_Per 90 Minutes  G_minus_PK_Per 90 Minutes  G+A_minus_PK_Per 90 Minutes  \
# ...

# %%
df['Squad'].unique()
# Out:
# array(['Bournemouth', 'Chelsea', 'Brighton', 'Wolves', 'Crystal Palace',
#        "Nott'ham Forest", 'Brentford', 'Manchester City', 'Southampton',
#        'Everton', 'Liverpool', 'Newcastle Utd', 'Leicester City',
#        'West Ham', 'Manchester Utd', 'Fulham', 'Aston Villa', 'Tottenham',
#        'Ipswich Town', 'Arsenal', 'Marseille', 'Saint-Étienne', 'Angers',
#        'Nice', 'Nantes', 'Lyon', 'Toulouse', 'Montpellier', 'Reims',
#        'Lens', 'Rennes', 'Brest', 'Monaco', 'Auxerre', 'Lille',
#        'Strasbourg', 'Paris S-G', 'Le Havre', 'Freiburg', 'Dortmund',
#        'Leverkusen', 'St. Pauli', 'Werder Bremen', 'Hoffenheim',
#        'Eint Frankfurt', 'Mainz 05', 'Wolfsburg', 'Holstein Kiel',
#        'Bayern Munich', 'Bochum', 'RB Leipzig', 'Augsburg', 'Heidenheim',
#        'Union Berlin', 'Stuttgart', 'Gladbach', 'Valencia', 'Getafe',
#        'Alavés', 'Sevilla', 'Betis', 'Athletic Club', 'Espanyol',
# ...
